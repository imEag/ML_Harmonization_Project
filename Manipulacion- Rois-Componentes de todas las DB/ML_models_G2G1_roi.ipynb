# %% [markdown]
# # Importación de librerías y carga de datos

# %%
"""
Modulo de entrenamiento para diferentes pipelines de ML para el
entrenamiento utilizando los datasets creados. El flujo es capaz de 
generalizar en la mayoría de los casos y únicamente es necesario
realizar modificaciones en la ruta a los datos.

"""
import os
import pandas as pd 
import seaborn as sns                                                   
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, \
                                    cross_val_score, \
                                    learning_curve, \
                                    RandomizedSearchCV, \
                                    GridSearchCV
from sklearn.inspection import permutation_importance
import numpy as np
from sklearn.svm import SVC
from sklearn import datasets, metrics
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from boruta import BorutaPy
from tpot import TPOTClassifier
import dataframe_image as dfi
from keras.models import Sequential,load_model,model_from_json
import itertools
import joblib  
from sklearn.metrics import confusion_matrix, recall_score, precision_score


path_santiago = r'C:\Users\santi\Universidad de Antioquia\VALERIA CADAVID CASTRO - Resultados_Armonizacion_BD'
path_veronica = r'C:\Users\veroh\OneDrive - Universidad de Antioquia\Articulo análisis longitudinal\Resultados_Armonizacion_BD'
path_save =r'C:\Users\veroh\OneDrive - Universidad de Antioquia\Articulo análisis longitudinal\Resultados_Armonizacion_BD\Graficos_ML'
name = 'neuroHarmonize_G2G1'
space = 'roi'
path_plot = path_save + '/' + name
os.makedirs(path_plot,exist_ok=True)

# %%
# compute precision and recall
def computerprecision(test_label,classes_x):
  precision_test = precision_score(test_label,classes_x)
  recall_test = recall_score(test_label, classes_x)
  f1_test = 2 * (precision_test * recall_test) / (precision_test + recall_test)
  print( 'Precision: ', precision_test, '\n', 'Recall: ', recall_test,'\n', 'F1-score:', f1_test )

# %%
def plot_confusion_matrix(path_plot,cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap='copper'):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(path_plot+'/'+'confusion_matrix.png')

# %%
path = path_veronica

# %%
modelos = {}
acc_per_feature = []
std_per_feature = []

# %%
data = pd.read_feather(r'{path}\Datosparaorganizardataframes\Data_complete_{space}_{name}.feather'
                       .format(path=path,space=space,name=name))

# %%
data
# Out:
#      power_F_Delta  power_C_Delta  power_PO_Delta  power_T_Delta  \
# 0         0.252443       0.196314        0.162268       0.087567
# 1         0.241997       0.215121        0.153380       0.151218
# 2         0.335102       0.234051        0.182968       0.107251
# 3         0.120671       0.083659        0.098290       0.081685
# 4         0.270239       0.271560        0.218584       0.255236
# ..             ...            ...             ...            ...
# 97        0.165091       0.134549        0.096337       0.140129
# 98        0.158650       0.122942        0.113321       0.141992
# 99        0.161124       0.145171        0.071499       0.105208
# 100       0.123753       0.140783        0.091015       0.110365
# 101       0.079070       0.076755        0.066611       0.078170
#
#      power_F_Theta  power_C_Theta  power_PO_Theta  power_T_Theta  \
# 0         0.057465       0.061586        0.046994       0.034215
# 1         0.126614       0.130534        0.109609       0.101573
# 2         0.117380       0.109618        0.069879       0.047876
# 3         0.146545       0.112676        0.139394       0.147712
# 4         0.108841       0.124055        0.115516       0.110494
# ..             ...            ...             ...            ...
# 97        0.090614       0.084518        0.084778       0.080064
# 98        0.139586       0.121145        0.134135       0.123517
# 99        0.075936       0.072617        0.046893       0.052678
# 100       0.133157       0.142083        0.126359       0.120884
# 101       0.076081       0.079229        0.083419       0.070100
#
#      power_F_Alpha-1  power_C_Alpha-1  ...  crossfreq_PO_Mbeta3_Gamma  \
# 0           0.077416         0.110643  ...                   0.136864
# 1           0.181439         0.195162  ...                   0.183135
# 2           0.056404         0.068819  ...                   0.118815
# 3           0.174043         0.209290  ...                   0.219752
# 4           0.118813         0.121848  ...                   0.079381
# ..               ...              ...  ...                        ...
# 97          0.143204         0.158106  ...                   0.160100
# 98          0.312415         0.310284  ...                   0.130863
# 99          0.134395         0.159797  ...                   0.233133
# 100         0.436249         0.386015  ...                   0.197572
# 101         0.434300         0.462399  ...                   0.255081
#
#      crossfreq_PO_Mgamma_Gamma  crossfreq_T_Mdelta_Gamma  \
# 0                     0.125778                 87.528584
# 1                     0.122927                 86.962346
# 2                     0.090539                 86.629791
# 3                     0.187225                 81.321139
# 4                     0.052161                 90.490457
# ..                         ...                       ...
# 97                    0.100744                 86.052435
# 98                    0.102041                 86.408299
# 99                    0.127854                 73.359858
# 100                   0.144015                 82.196798
# 101                   0.250396                 82.544081
#
#      crossfreq_T_Mtheta_Gamma  crossfreq_T_Malpha-1_Gamma  \
# 0                    2.598879                    0.318691
# 1                    3.401882                    0.409069
# 2                    3.324346                    0.410627
# 3                    5.451389                    0.589188
# 4                    2.641156                    0.334063
# ..                        ...                         ...
# 97                   3.289697                    0.411461
# 98                   3.454451                    0.512532
# 99                   2.937936                    0.487644
# 100                  4.086555                    0.656925
# 101                  3.957733                    0.534683
#
#      crossfreq_T_Malpha-2_Gamma  crossfreq_T_Mbeta1_Gamma  \
# 0                      0.186796                  0.365122
# 1                      0.194751                  0.359669
# 2                      0.229236                  0.349062
# 3                      0.300113                  0.419769
# 4                      0.160354                  0.227812
# ..                          ...                       ...
# 97                     0.247015                  0.431137
# 98                     0.239650                  0.360471
# 99                     0.317345                  1.031380
# 100                    0.380047                  0.486379
# 101                    0.291005                  0.478985
#
#      crossfreq_T_Mbeta2_Gamma  crossfreq_T_Mbeta3_Gamma  \
# 0                    0.090492                  0.174844
# 1                    0.089835                  0.148822
# 2                    0.085747                  0.166171
# 3                    0.106882                  0.175754
# 4                    0.055880                  0.083832
# ..                        ...                       ...
# 97                   0.107572                  0.151162
# 98                   0.086022                  0.126728
# 99                   0.238377                  0.646712
# 100                  0.122264                  0.185436
# 101                  0.126664                  0.224144
#
#      crossfreq_T_Mgamma_Gamma
# 0                    0.255118
# 1                    0.118253
# 2                    0.154658
# 3                    0.132286
# 4                    0.070946
# ..                        ...
# 97                   0.119375
# 98                   0.089586
# 99                   0.805156
# 100                  0.145602
# 101                  0.209853
#
# [102 rows x 396 columns]

# %%
print(f'sujetos: {data.shape[0]} | caracteristicas: {data.shape[1]}')
# Out:
# sujetos: 102 | caracteristicas: 396

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
for group in data['group'].unique():
        
        print('{} : {}'.format(group, (data['group']==group).sum()))
# Out:
# G1 : 48
# G2 : 54

# %%
data.describe()
# Out:
#        power_F_Delta  power_C_Delta  power_PO_Delta  power_T_Delta  \
# count     102.000000     102.000000      102.000000     102.000000
# mean        0.201022       0.170847        0.140810       0.150865
# std         0.079439       0.072223        0.071777       0.069321
# min         0.069051       0.057993        0.046261       0.041844
# 25%         0.143297       0.118636        0.086932       0.105609
# 50%         0.192125       0.150630        0.114155       0.138814
# 75%         0.244500       0.214635        0.175596       0.175011
# max         0.423865       0.358763        0.318207       0.348100
#
#        power_F_Theta  power_C_Theta  power_PO_Theta  power_T_Theta  \
# count     102.000000     102.000000      102.000000     102.000000
# mean        0.118835       0.113172        0.111598       0.102646
# std         0.055555       0.054221        0.065365       0.054278
# min         0.047123       0.044487        0.035616       0.028267
# 25%         0.078726       0.077458        0.069065       0.063314
# 50%         0.104856       0.096133        0.087469       0.088799
# 75%         0.136294       0.136972        0.139078       0.130424
# max         0.333359       0.294264        0.369383       0.282400
#
#        power_F_Alpha-1  power_C_Alpha-1  ...  crossfreq_PO_Mbeta3_Gamma  \
# count       102.000000       102.000000  ...                 102.000000
# mean          0.212090         0.216305  ...                   0.155285
# std           0.108212         0.100023  ...                   0.069177
# min           0.053807         0.066887  ...                   0.052524
# 25%           0.121111         0.124357  ...                   0.101382
# 50%           0.189481         0.207466  ...                   0.151501
# 75%           0.301705         0.295147  ...                   0.182644
# max           0.436249         0.462399  ...                   0.392302
#
#        crossfreq_PO_Mgamma_Gamma  crossfreq_T_Mdelta_Gamma  \
# count                 102.000000                102.000000
# mean                    0.118073                 85.245488
# std                     0.065710                  4.598270
# min                     0.036941                 68.447946
# 25%                     0.081963                 82.623898
# 50%                     0.105567                 86.194824
# 75%                     0.134991                 88.591640
# max                     0.538688                 92.000344
#
#        crossfreq_T_Mtheta_Gamma  crossfreq_T_Malpha-1_Gamma  \
# count                102.000000                  102.000000
# mean                   3.389038                    0.458925
# std                    0.766441                    0.122503
# min                    2.089076                    0.251946
# 25%                    2.891687                    0.355059
# 50%                    3.259226                    0.440655
# 75%                    3.925665                    0.546231
# max                    6.056837                    0.776802
#
#        crossfreq_T_Malpha-2_Gamma  crossfreq_T_Mbeta1_Gamma  \
# count                  102.000000                102.000000
# mean                     0.244565                  0.426548
# std                      0.082853                  0.204320
# min                      0.129252                  0.140072
# 25%                      0.172403                  0.289690
# 50%                      0.233933                  0.364838
# 75%                      0.293811                  0.485155
# max                      0.506423                  1.041848
#
#        crossfreq_T_Mbeta2_Gamma  crossfreq_T_Mbeta3_Gamma  \
# count                102.000000                102.000000
# mean                   0.102617                  0.182162
# std                    0.045669                  0.123255
# min                    0.035362                  0.046389
# 25%                    0.071957                  0.111252
# 50%                    0.090435                  0.148615
# 75%                    0.121450                  0.206757
# max                    0.238377                  0.687899
#
#        crossfreq_T_Mgamma_Gamma
# count                102.000000
# mean                   0.194221
# std                    0.233766
# min                    0.039909
# 25%                    0.087112
# 50%                    0.129995
# 75%                    0.186482
# max                    1.579598
#
# [8 rows x 390 columns]

# %%
data.groupby(by='group').describe().T
# Out:
# group                                  G1         G2
# power_F_Delta            count  48.000000  54.000000
#                          mean    0.201048   0.200999
#                          std     0.075483   0.083506
#                          min     0.082985   0.069051
#                          25%     0.147466   0.143297
# ...                                   ...        ...
# crossfreq_T_Mgamma_Gamma min     0.055665   0.039909
#                          25%     0.097546   0.081250
#                          50%     0.145504   0.114910
#                          75%     0.195951   0.169383
#                          max     1.579598   0.995951
#
# [3120 rows x 2 columns]

# %%
# eliminación de columnas con datos faltantes

for column in data.columns:

    if data[column].isna().sum() != 0:

        print('{} : {}'.format(column, (data[column].isna().sum())))
        data.drop(column, axis=1, inplace=True)
# Out:
# FAS_F : 41
# FAS_S : 41
# FAS_A : 41

# %%
print(f'sujetos: {data.shape[0]} | caracteristicas: {data.shape[1]}')
# Out:
# sujetos: 102 | caracteristicas: 393

# %%
# Se mapean las clases 

clases_mapeadas = {label:idx for idx,label  
                   in enumerate(np.unique(data['group']))}

data.loc[:,'group'] = data.loc[:,'group'].map(clases_mapeadas) 
print(clases_mapeadas)
# Out:
# {'G1': 0, 'G2': 1}
# C:\Users\veroh\AppData\Local\Temp\ipykernel_104656\383920285.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.loc[:,'group'] = data.loc[:,'group'].map(clases_mapeadas)

# %%
print(data.dtypes.unique())
# Out:
# [dtype('float64') dtype('O') dtype('int64')]

# %%
data.select_dtypes('O')
# Out:
#           database participant_id visit condition sex
# 0    BIOMARCADORES      sub-G1024    V0        CE   M
# 1    BIOMARCADORES      sub-G1023    V0        CE   F
# 2    BIOMARCADORES      sub-G1022    V0        CE   F
# 3    BIOMARCADORES      sub-G1021    V0        CE   F
# 4    BIOMARCADORES      sub-G1019    V0        CE   F
# ..             ...            ...   ...       ...  ..
# 97           DUQUE    sub-ALZS019    V0   resting   F
# 98           DUQUE    sub-ALZS008    V0   resting   M
# 99           DUQUE    sub-ALZS022    V0   resting   M
# 100          DUQUE    sub-ALZS014    V0   resting   M
# 101          DUQUE    sub-ALZS007    V0   resting   F
#
# [102 rows x 5 columns]

# %%
data.groupby(by='sex').describe().T
# Out:
# sex                                     F          M
# power_F_Delta            count  61.000000  41.000000
#                          mean    0.194207   0.211161
#                          std     0.077539   0.082095
#                          min     0.069051   0.097294
#                          25%     0.138233   0.158650
# ...                                   ...        ...
# crossfreq_T_Mgamma_Gamma min     0.055313   0.039909
#                          25%     0.091609   0.077040
#                          50%     0.130411   0.124754
#                          75%     0.187560   0.184958
#                          max     1.175255   1.579598
#
# [3104 rows x 2 columns]

# %%
sexo_mapeado = {label:idx for idx,label
                in enumerate(np.unique(data['sex']))}

data.loc[:,'sex'] = data.loc[:,'sex'].map(sexo_mapeado) 
print(sexo_mapeado)
# Out:
# {'F': 0, 'M': 1}
# C:\Users\veroh\AppData\Local\Temp\ipykernel_104656\2216644689.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.loc[:,'sex'] = data.loc[:,'sex'].map(sexo_mapeado)

# %%
# data pasa a ser el arreglo únicamente con los datos númericos

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

data = data.select_dtypes(include=numerics)

data.shape
# Out:
# (102, 389)

# %%
# Se elimina la columna, para ponerla al final

target = data.pop('group')
data.insert(len(data.columns), target.name, target)

# %% [markdown]
# ## Selección de caracteristicas

# %% [markdown]
# ### Creación de datasets de entrenamiento y test

# %%
X = data.values[:,:-1]
y = data.values[:,-1]
print(X.shape)
print(y.shape)
# Out:
# (102, 388)
# (102,)

# %%
X_train, X_test, y_train, y_test = train_test_split(                            
    X, # Valores de X
    y, # Valores de Y
    test_size=0.2, # Test de 20%
    random_state=1, # Semilla
    stratify=data.values[:,-1]) # que se mantenga la proporcion en la división

# %% [markdown]
# ### Mapa de calor de correlación

# %%
sns.heatmap(data.corr())
plt.savefig(path_plot+'/'+'correlation.png')

# %% [markdown]
# ### Árboles de decisión (Grid Search)

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 30)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
criterion = ['gini',  'entropy', 'log_loss']

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion': criterion
               }

# %%
forestclf_grid = RandomForestClassifier()

rf_random = RandomizedSearchCV(
                              estimator=forestclf_grid,
                              param_distributions=random_grid,
                              n_iter=100,
                              cv=10,
                              verbose=2,
                              random_state=10,
                              n_jobs=-1
                              )

rf_random.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 13
#       1 forestclf_grid = RandomForestClassifier()
#       3 rf_random = RandomizedSearchCV(
#       4                               estimator=forestclf_grid,
#       5                               param_distributions=random_grid,
#    (...)
#      10                               n_jobs=-1
#      11                               )
# ---> 13 rf_random.fit(X_train, y_train)
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\veroh\anaconda3\lib\site-packages\joblib\parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File c:\Users\veroh\anaconda3\lib\site-packages\joblib\parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File c:\Users\veroh\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File c:\Users\veroh\anaconda3\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File c:\Users\veroh\anaconda3\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
best_selected = rf_random.best_estimator_

# %%
GS_fitted = best_selected.fit(X_train, y_train)
modelos['GridSerach'] = GS_fitted

# %%
predicted = GS_fitted.predict(X_test)

# %%
print(
    f"Classification report for classifier {GS_fitted}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
    )
# Out:
# Classification report for classifier RandomForestClassifier(criterion='entropy', max_depth=20):
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.20      0.24        10
#          1.0       0.43      0.55      0.48        11
#
#     accuracy                           0.38        21
#    macro avg       0.36      0.37      0.36        21
# weighted avg       0.36      0.38      0.36        21

# %%
dataframe_metrics = metrics.classification_report(y_test, predicted, output_dict=True)
dataframe_metrics = pd.DataFrame(dataframe_metrics).T
dfi.export(dataframe_metrics, path_plot+'/'+'metrics.png')
# Out:
# C:\Program Files\Google\Chrome\Application\chrome.exe

# %%
scores = cross_val_score(
                        estimator=GS_fitted,
                        X=X_train,
                        y=y_train,
                        cv=10,
                        n_jobs=-1
                        )

# %%
print('CV accuracy scores: %s' % scores)
# Out:
# CV accuracy scores: [0.88888889 0.75       0.625      0.625      0.625      0.5
#  1.         0.375      0.75       0.625     ]

# %%
print('\nCV accuracy: %.3f +/- %.3f' %
    (np.mean(scores), np.std(scores)))

acc_per_feature.append(np.mean(scores))
std_per_feature.append(np.std(scores))
# Out:
# CV accuracy: 0.676 +/- 0.171

# %%
train_sizes, train_scores, test_scores = \
    learning_curve(
                  estimator=GS_fitted,
                  X=X_train,
                  y=y_train,
                  train_sizes=np.linspace(0.1, 1, 10),
                  cv=10,
                  n_jobs=-1
                  )
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(
        train_sizes,
        train_mean,
        color='blue',
        marker='o',
        markersize=5,
        label='training accuracy'
        )

plt.fill_between(
                train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15,
                color='blue'
                )

plt.plot(
        train_sizes,
        test_mean,
        color='green',
        linestyle='--',
        marker='s',
        markersize=5,
        label='validation accuracy'
        )

plt.fill_between(
                train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15,
                color='green'
                )

plt.grid()
plt.xlabel('number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.5, 1.0])
plt.savefig(path_plot+'/'+'validation_GridSearch.png')
plt.show()

# %% [markdown]
# ### Árboles de decisión (Boruta)

# %%
feat_selector = BorutaPy(
                        verbose=2,
                        estimator=best_selected,
                        max_iter=100,
                        random_state=10
                        )

# %%
feat_selector.fit(X_train, y_train)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	388
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	19 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	20 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	21 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	378
# Iteration: 	22 / 100
# Confirmed: 	1
# Tentative: 	9
# Rejected: 	378
# Iteration: 	23 / 100
# Confirmed: 	1
# Tentative: 	9
# Rejected: 	378
# Iteration: 	24 / 100
# Confirmed: 	1
# Tentative: 	9
# Rejected: 	378
# Iteration: 	25 / 100
# Confirmed: 	1
# Tentative: 	9
# Rejected: 	378
# Iteration: 	26 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	27 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	28 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	29 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	30 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	31 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	32 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	33 / 100
# Confirmed: 	2
# Tentative: 	8
# Rejected: 	378
# Iteration: 	34 / 100
# Confirmed: 	6
# Tentative: 	4
# Rejected: 	378
# Iteration: 	35 / 100
# Confirmed: 	6
# Tentative: 	4
# Rejected: 	378
# Iteration: 	36 / 100
# Confirmed: 	6
# Tentative: 	4
# Rejected: 	378
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	57 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	58 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	59 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	60 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	61 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	378
# Iteration: 	62 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	63 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	64 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	65 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	66 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	67 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	68 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	69 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	70 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	71 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	72 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	73 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	74 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	75 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	76 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	77 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	78 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	79 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	80 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	81 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	82 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	83 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	84 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	85 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	86 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	87 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	378
# Iteration: 	88 / 100
# Confirmed: 	10
# Tentative: 	0
# Rejected: 	378
#
#
# BorutaPy finished running.
#
# Iteration: 	89 / 100
# Confirmed: 	10
# Tentative: 	0
# Rejected: 	378
# BorutaPy(estimator=RandomForestClassifier(criterion='entropy', max_depth=20,
#                                           n_estimators=1000,
#                                           random_state=RandomState(MT19937) at 0x177DB9FAC40),
#          random_state=RandomState(MT19937) at 0x177DB9FAC40, verbose=2)

# %%
selected_features = []
print("\n------Support and Ranking for each feature------")
for i in range(len(feat_selector.support_)):
    if feat_selector.support_[i]:
        print("Passes the test: ", data.columns[i],
              " - Ranking: ", feat_selector.ranking_[i])
        selected_features.append(data.columns[i])
# Out:
# ------Support and Ranking for each feature------
# Passes the test:  sl_C_Delta  - Ranking:  1
# Passes the test:  sl_C_Gamma  - Ranking:  1
# Passes the test:  sl_PO_Gamma  - Ranking:  1
# Passes the test:  cohfreq_C_Delta  - Ranking:  1
# Passes the test:  cohfreq_PO_Beta2  - Ranking:  1
# Passes the test:  cohfreq_F_Beta3  - Ranking:  1
# Passes the test:  crossfreq_T_Mbeta1_Theta  - Ranking:  1
# Passes the test:  crossfreq_T_Mdelta_Beta2  - Ranking:  1
# Passes the test:  crossfreq_T_Mbeta1_Beta2  - Ranking:  1
# Passes the test:  crossfreq_T_Mbeta2_Beta2  - Ranking:  1

# %%
X_transform = feat_selector.transform(X_train)

# %%
boruta_fitted = best_selected.fit(X_transform, y_train)
modelos['Boruta'] = boruta_fitted

# %%
selected_features = [data.columns.get_loc(c) for c in selected_features if c in data]
selected_features
# Out:
# [37, 65, 66, 69, 90, 92, 192, 316, 320, 321]

# %%
predicted = boruta_fitted.predict(X_test[:,selected_features])

# %%
print(
    f"Classification report for classifier {boruta_fitted}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)
# Out:
# Classification report for classifier RandomForestClassifier(criterion='entropy', max_depth=20, n_estimators=1000,
#                        random_state=RandomState(MT19937) at 0x177DB9FAC40):
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.40      0.44        10
#          1.0       0.54      0.64      0.58        11
#
#     accuracy                           0.52        21
#    macro avg       0.52      0.52      0.51        21
# weighted avg       0.52      0.52      0.52        21

# %%
dataframe_metrics = metrics.classification_report(y_test, predicted, output_dict=True)
dataframe_metrics = pd.DataFrame(dataframe_metrics).T
dfi.export(dataframe_metrics, path_plot+'/'+'metrics_boruta.png')
# Out:
# C:\Program Files\Google\Chrome\Application\chrome.exe

# %%
scores = cross_val_score(estimator=boruta_fitted,
                        X=X_transform,
                        y=y_train,
                        cv=10,
                        n_jobs=-1)

# %%
print('CV accuracy scores: %s' % scores)
# Out:
# CV accuracy scores: [0.66666667 0.875      0.625      0.875      0.75       0.5
#  1.         0.875      0.75       0.75      ]

# %%
print('\nCV accuracy: %.3f +/- %.3f' %
    (np.mean(scores), np.std(scores)))


acc_per_feature.append(np.mean(scores))
std_per_feature.append(np.std(scores))
# Out:
# CV accuracy: 0.767 +/- 0.138

# %%
train_sizes, train_scores, test_scores = \
    learning_curve(
                  estimator=boruta_fitted,
                  X=X_transform,
                  y=y_train,
                  train_sizes=np.linspace(0.1, 1, 10),
                  cv=10,
                  n_jobs=-1
                  )
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(
        train_sizes,
        train_mean,
        color='blue',
        marker='o',
        markersize=5,
        label='training accuracy'
        )

plt.fill_between(
                train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15,
                color='blue'
                )

plt.plot(
        train_sizes,
        test_mean,
        color='green',
        linestyle='--',
        marker='s',
        markersize=5,
        label='validation accuracy'
        )

plt.fill_between(
                train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15,
                color='green'
                )

plt.grid()
plt.xlabel('number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.5, 1.0])
plt.savefig(path_plot+'/'+'validation_Boruta.png')
plt.show()

# %% [markdown]
# ### Selección de caracteristicas con árboles de decisión

# %%
nombres_columnas = data.columns[:-1]
best_selected.fit(X_train, y_train)
features_scores = best_selected.feature_importances_
features_scores
index = np.argsort(features_scores)[::-1]
sorted_names = []

for f in range(X_train.shape[1]):

    sorted_names.append(nombres_columnas[index[f]])
    print("%2d) %-*s %f" % (f + 1, 30,
                        nombres_columnas[index[f]],
                        features_scores[index[f]]))
    
plt.title('Importancia de la caracteristica')

plt.bar(range(X_train.shape[1]),
    features_scores[index],
    align='center')

plt.xticks(range(X_train.shape[1]),
    nombres_columnas[index],
    rotation=90)

plt.xlim([-1, 10])

plt.tight_layout()

plt.show()
# Out:
#  1) sl_PO_Gamma                    0.018413
#  2) cohfreq_PO_Beta2               0.013414
#  3) sl_C_Delta                     0.011489
#  4) cohfreq_F_Beta2                0.011316
#  5) cohfreq_F_Beta3                0.010166
#  6) crossfreq_T_Mgamma_Delta       0.009512
#  7) sl_F_Gamma                     0.009215
#  8) cohfreq_C_Delta                0.009163
#  9) sl_C_Gamma                     0.009054
# 10) crossfreq_T_Mbeta2_Beta2       0.009025
# 11) crossfreq_T_Mdelta_Beta2       0.008322
# 12) crossfreq_T_Mbeta1_Beta2       0.008009
# 13) cohfreq_C_Beta2                0.007663
# 14) cohfreq_T_Beta2                0.007430
# 15) sl_F_Delta                     0.007326
# 16) cohfreq_F_Beta1                0.006974
# 17) crossfreq_PO_Mgamma_Alpha-1    0.006467
# 18) crossfreq_T_Mbeta1_Theta       0.006434
# 19) crossfreq_T_Mbeta2_Theta       0.006427
# 20) crossfreq_T_Malpha-2_Beta2     0.006321
# 21) crossfreq_T_Malpha-2_Alpha-1   0.006034
# 22) crossfreq_PO_Mgamma_Beta3      0.006018
# 23) crossfreq_T_Mbeta3_Delta       0.005935
# 24) crossfreq_F_Mbeta3_Beta1       0.005627
# 25) sl_F_Beta3                     0.005591
# 26) sl_T_Gamma                     0.005454
# 27) sl_F_Beta2                     0.005419
# 28) cohfreq_PO_Alpha-2             0.005132
# 29) crossfreq_T_Mgamma_Theta       0.005076
# 30) cohfreq_PO_Beta1               0.004949
# 31) sl_F_Beta1                     0.004721
# 32) cohfreq_T_Beta1                0.004676
# 33) crossfreq_PO_Mbeta3_Alpha-1    0.004613
# 34) power_PO_Beta1                 0.004503
# 35) crossfreq_T_Malpha-1_Beta2     0.004366
# 36) cohfreq_F_Alpha-1              0.004325
# 37) crossfreq_PO_Malpha-1_Theta    0.004293
# 38) entropy_C_Beta1                0.004247
# 39) crossfreq_T_Malpha-2_Theta     0.004228
# 40) crossfreq_PO_Malpha-2_Theta    0.004212
# 41) sl_PO_Theta                    0.004090
# 42) crossfreq_PO_Malpha-2_Alpha-1  0.004086
# 43) sl_F_Theta                     0.004059
# 44) crossfreq_C_Mdelta_Gamma       0.004045
# 45) crossfreq_C_Mtheta_Beta2       0.003994
# 46) power_F_Beta3                  0.003905
# 47) entropy_PO_Beta2               0.003901
# 48) crossfreq_C_Mgamma_Delta       0.003897
# 49) crossfreq_C_Mdelta_Alpha-2     0.003834
# 50) crossfreq_PO_Malpha-2_Alpha-2  0.003775
# 51) crossfreq_PO_Malpha-2_Delta    0.003758
# 52) crossfreq_PO_Mgamma_Beta1      0.003716
# 53) crossfreq_PO_Mbeta2_Theta      0.003685
# 54) crossfreq_C_Mtheta_Beta3       0.003676
# 55) cohfreq_F_Theta                0.003662
# 56) crossfreq_PO_Mbeta1_Beta2      0.003651
# 57) cohfreq_PO_Alpha-1             0.003645
# 58) crossfreq_F_Mbeta3_Beta3       0.003622
# 59) crossfreq_C_Mbeta3_Alpha-2     0.003620
# 60) crossfreq_F_Mbeta2_Beta1       0.003619
# 61) crossfreq_F_Mtheta_Beta3       0.003618
# 62) crossfreq_PO_Malpha-2_Gamma    0.003571
# 63) crossfreq_PO_Malpha-1_Alpha-1  0.003550
# 64) crossfreq_T_Mbeta3_Beta2       0.003542
# 65) crossfreq_PO_Mtheta_Alpha-1    0.003540
# 66) crossfreq_C_Mdelta_Beta3       0.003514
# 67) power_T_Beta1                  0.003501
# 68) power_C_Beta3                  0.003466
# 69) sl_T_Delta                     0.003463
# 70) crossfreq_PO_Mgamma_Theta      0.003460
# 71) entropy_PO_Beta3               0.003452
# 72) sl_F_Alpha-1                   0.003437
# 73) crossfreq_PO_Malpha-1_Delta    0.003413
# 74) crossfreq_C_Mdelta_Beta2       0.003396
# 75) crossfreq_PO_Mgamma_Gamma      0.003387
# 76) power_C_Beta1                  0.003341
# 77) crossfreq_C_Malpha-2_Beta3     0.003331
# 78) crossfreq_C_Mdelta_Delta       0.003284
# 79) crossfreq_C_Mtheta_Gamma       0.003264
# 80) cohfreq_C_Alpha-2              0.003259
# 81) entropy_T_Alpha-2              0.003250
# 82) crossfreq_PO_Mgamma_Delta      0.003241
# 83) crossfreq_F_Mgamma_Beta1       0.003237
# 84) cohfreq_C_Beta1                0.003221
# 85) cohfreq_C_Beta3                0.003197
# 86) crossfreq_C_Mbeta3_Gamma       0.003189
# 87) crossfreq_C_Mbeta1_Alpha-2     0.003186
# 88) crossfreq_T_Mbeta1_Delta       0.003163
# 89) crossfreq_PO_Mdelta_Gamma      0.003157
# 90) crossfreq_F_Malpha-2_Alpha-2   0.003111
# 91) crossfreq_F_Mgamma_Beta3       0.003091
# 92) crossfreq_F_Mbeta1_Beta1       0.003083
# 93) cohfreq_PO_Beta3               0.003067
# 94) crossfreq_C_Mdelta_Beta1       0.003062
# 95) crossfreq_PO_Malpha-2_Beta2    0.003052
# 96) entropy_PO_Gamma               0.003039
# 97) crossfreq_F_Malpha-2_Beta2     0.003026
# 98) cohfreq_T_Theta                0.002999
# 99) crossfreq_T_Mgamma_Beta2       0.002907
# 100) sl_PO_Beta3                    0.002892
# 101) power_C_Theta                  0.002865
# 102) cohfreq_PO_Theta               0.002860
# 103) crossfreq_PO_Malpha-1_Gamma    0.002842
# 104) crossfreq_T_Malpha-2_Beta3     0.002826
# 105) crossfreq_PO_Mdelta_Theta      0.002819
# 106) crossfreq_T_Malpha-2_Alpha-2   0.002808
# 107) crossfreq_T_Mbeta1_Alpha-1     0.002806
# 108) crossfreq_C_Mtheta_Beta1       0.002793
# 109) crossfreq_PO_Mdelta_Alpha-2    0.002788
# 110) crossfreq_PO_Mgamma_Beta2      0.002779
# 111) sl_PO_Alpha-1                  0.002774
# 112) entropy_F_Beta1                0.002774
# 113) crossfreq_PO_Mbeta3_Theta      0.002765
# 114) crossfreq_PO_Mtheta_Theta      0.002745
# 115) crossfreq_T_Mbeta2_Delta       0.002708
# 116) entropy_C_Beta2                0.002708
# 117) crossfreq_C_Mbeta3_Theta       0.002705
# 118) crossfreq_PO_Mbeta3_Gamma      0.002696
# 119) cohfreq_T_Beta3                0.002685
# 120) sl_C_Theta                     0.002678
# 121) sl_PO_Beta1                    0.002678
# 122) crossfreq_PO_Mbeta2_Alpha-1    0.002673
# 123) sl_T_Alpha-1                   0.002669
# 124) crossfreq_T_Malpha-1_Beta3     0.002647
# 125) cohfreq_PO_Gamma               0.002642
# 126) crossfreq_PO_Mbeta3_Beta1      0.002627
# 127) crossfreq_F_Mbeta1_Beta3       0.002622
# 128) cohfreq_C_Theta                0.002617
# 129) crossfreq_T_Mbeta3_Alpha-1     0.002615
# 130) power_C_Alpha-2                0.002611
# 131) crossfreq_PO_Mbeta1_Theta      0.002600
# 132) crossfreq_C_Mbeta3_Delta       0.002599
# 133) crossfreq_T_Mdelta_Theta       0.002587
# 134) crossfreq_F_Mbeta2_Theta       0.002555
# 135) sl_T_Beta2                     0.002537
# 136) entropy_F_Gamma                0.002531
# 137) crossfreq_C_Mbeta2_Gamma       0.002517
# 138) crossfreq_PO_Mbeta3_Alpha-2    0.002511
# 139) crossfreq_PO_Mbeta2_Beta2      0.002509
# 140) crossfreq_T_Mtheta_Beta2       0.002508
# 141) sl_PO_Beta2                    0.002507
# 142) crossfreq_T_Mdelta_Alpha-1     0.002505
# 143) crossfreq_F_Mgamma_Gamma       0.002501
# 144) power_T_Delta                  0.002497
# 145) crossfreq_T_Malpha-1_Alpha-1   0.002482
# 146) crossfreq_T_Mbeta2_Alpha-1     0.002471
# 147) crossfreq_F_Mtheta_Theta       0.002471
# 148) cohfreq_F_Delta                0.002467
# 149) crossfreq_PO_Mbeta3_Beta3      0.002465
# 150) power_F_Alpha-2                0.002456
# 151) crossfreq_T_Mbeta2_Beta1       0.002454
# 152) crossfreq_F_Mgamma_Alpha-2     0.002449
# 153) crossfreq_PO_Malpha-1_Alpha-2  0.002442
# 154) sl_C_Beta3                     0.002431
# 155) crossfreq_F_Mbeta2_Beta3       0.002416
# 156) entropy_PO_Beta1               0.002394
# 157) crossfreq_C_Malpha-2_Delta     0.002386
# 158) sl_C_Beta2                     0.002386
# 159) cohfreq_F_Gamma                0.002381
# 160) crossfreq_T_Mbeta2_Beta3       0.002381
# 161) age                            0.002367
# 162) crossfreq_C_Malpha-2_Beta2     0.002362
# 163) crossfreq_T_Mbeta3_Beta3       0.002359
# 164) power_F_Beta1                  0.002349
# 165) crossfreq_PO_Mtheta_Gamma      0.002333
# 166) power_PO_Alpha-2               0.002324
# 167) power_F_Theta                  0.002322
# 168) crossfreq_F_Mdelta_Beta1       0.002320
# 169) crossfreq_F_Malpha-1_Beta1     0.002317
# 170) sl_PO_Delta                    0.002315
# 171) sl_C_Alpha-2                   0.002297
# 172) crossfreq_C_Mgamma_Alpha-2     0.002287
# 173) crossfreq_T_Mtheta_Alpha-1     0.002283
# 174) entropy_T_Beta1                0.002270
# 175) crossfreq_PO_Mbeta3_Beta2      0.002251
# 176) crossfreq_PO_Malpha-1_Beta2    0.002249
# 177) crossfreq_T_Mbeta3_Theta       0.002248
# 178) crossfreq_T_Mgamma_Beta3       0.002232
# 179) cohfreq_F_Alpha-2              0.002217
# 180) crossfreq_C_Mgamma_Beta2       0.002216
# 181) power_PO_Gamma                 0.002215
# 182) crossfreq_T_Mgamma_Gamma       0.002204
# 183) crossfreq_F_Malpha-2_Theta     0.002194
# 184) entropy_PO_Theta               0.002190
# 185) crossfreq_PO_Mtheta_Beta2      0.002186
# 186) entropy_T_Beta3                0.002179
# 187) crossfreq_F_Mgamma_Delta       0.002172
# 188) cohfreq_T_Gamma                0.002168
# 189) crossfreq_F_Mtheta_Alpha-2     0.002160
# 190) cohfreq_T_Alpha-1              0.002144
# 191) crossfreq_T_Malpha-1_Theta     0.002130
# 192) crossfreq_PO_Malpha-2_Beta3    0.002121
# 193) sl_T_Beta3                     0.002102
# 194) crossfreq_F_Mdelta_Gamma       0.002098
# 195) power_T_Alpha-2                0.002094
# 196) crossfreq_PO_Mgamma_Alpha-2    0.002064
# 197) crossfreq_PO_Malpha-2_Beta1    0.002053
# 198) power_PO_Theta                 0.002036
# 199) crossfreq_F_Mtheta_Gamma       0.002031
# 200) crossfreq_F_Mbeta3_Theta       0.002030
# 201) cohfreq_C_Gamma                0.002030
# 202) entropy_T_Delta                0.002024
# 203) entropy_PO_Alpha-1             0.002013
# 204) entropy_C_Alpha-1              0.001984
# 205) crossfreq_T_Malpha-1_Alpha-2   0.001980
# 206) power_F_Gamma                  0.001971
# 207) crossfreq_C_Mgamma_Beta3       0.001947
# 208) cohfreq_PO_Delta               0.001945
# 209) crossfreq_PO_Mbeta1_Alpha-1    0.001939
# 210) crossfreq_F_Mdelta_Theta       0.001937
# 211) entropy_F_Beta3                0.001934
# 212) crossfreq_T_Mdelta_Delta       0.001933
# 213) crossfreq_F_Mbeta3_Beta2       0.001930
# 214) sl_T_Beta1                     0.001913
# 215) crossfreq_PO_Mdelta_Beta1      0.001909
# 216) entropy_PO_Alpha-2             0.001895
# 217) crossfreq_PO_Mdelta_Delta      0.001895
# 218) cohfreq_T_Delta                0.001889
# 219) crossfreq_C_Mgamma_Theta       0.001888
# 220) crossfreq_F_Mbeta2_Delta       0.001883
# 221) crossfreq_C_Malpha-2_Alpha-1   0.001882
# 222) crossfreq_C_Malpha-1_Alpha-2   0.001873
# 223) crossfreq_T_Mdelta_Beta1       0.001871
# 224) crossfreq_PO_Mbeta1_Beta1      0.001864
# 225) crossfreq_PO_Malpha-1_Beta1    0.001862
# 226) entropy_F_Alpha-1              0.001862
# 227) cohfreq_C_Alpha-1              0.001861
# 228) crossfreq_F_Mgamma_Beta2       0.001841
# 229) crossfreq_F_Mdelta_Alpha-1     0.001832
# 230) crossfreq_F_Mdelta_Delta       0.001828
# 231) entropy_PO_Delta               0.001826
# 232) crossfreq_C_Mbeta3_Beta2       0.001809
# 233) crossfreq_T_Mgamma_Alpha-2     0.001805
# 234) crossfreq_C_Mbeta2_Alpha-2     0.001787
# 235) crossfreq_T_Mtheta_Theta       0.001768
# 236) sl_C_Alpha-1                   0.001768
# 237) crossfreq_C_Mgamma_Alpha-1     0.001766
# 238) entropy_T_Alpha-1              0.001765
# 239) crossfreq_T_Mtheta_Beta3       0.001760
# 240) crossfreq_PO_Mbeta1_Alpha-2    0.001753
# 241) entropy_F_Delta                0.001750
# 242) crossfreq_PO_Mdelta_Beta3      0.001730
# 243) crossfreq_F_Mgamma_Theta       0.001728
# 244) crossfreq_C_Malpha-1_Gamma     0.001719
# 245) crossfreq_F_Malpha-2_Gamma     0.001718
# 246) crossfreq_T_Mdelta_Alpha-2     0.001710
# 247) entropy_T_Gamma                0.001708
# 248) sl_C_Beta1                     0.001701
# 249) crossfreq_C_Mgamma_Gamma       0.001695
# 250) entropy_C_Alpha-2              0.001666
# 251) crossfreq_F_Mtheta_Alpha-1     0.001664
# 252) crossfreq_T_Mbeta3_Gamma       0.001662
# 253) power_T_Beta3                  0.001659
# 254) entropy_C_Delta                0.001656
# 255) power_PO_Delta                 0.001651
# 256) power_T_Gamma                  0.001647
# 257) crossfreq_F_Mbeta2_Alpha-2     0.001645
# 258) crossfreq_PO_Mdelta_Beta2      0.001625
# 259) crossfreq_T_Mtheta_Alpha-2     0.001623
# 260) crossfreq_C_Malpha-1_Theta     0.001620
# 261) power_C_Beta2                  0.001612
# 262) crossfreq_T_Malpha-1_Gamma     0.001611
# 263) crossfreq_T_Mbeta3_Alpha-2     0.001606
# 264) crossfreq_C_Malpha-1_Delta     0.001605
# 265) crossfreq_F_Mdelta_Beta2       0.001604
# 266) crossfreq_PO_Mbeta2_Delta      0.001595
# 267) power_PO_Alpha-1               0.001570
# 268) crossfreq_F_Mtheta_Beta1       0.001561
# 269) crossfreq_C_Mbeta3_Alpha-1     0.001555
# 270) crossfreq_T_Mbeta2_Alpha-2     0.001552
# 271) entropy_F_Alpha-2              0.001551
# 272) crossfreq_C_Mbeta3_Beta3       0.001550
# 273) crossfreq_PO_Mbeta2_Beta1      0.001541
# 274) power_PO_Beta2                 0.001535
# 275) cohfreq_T_Alpha-2              0.001532
# 276) crossfreq_T_Malpha-2_Delta     0.001530
# 277) crossfreq_C_Malpha-2_Theta     0.001528
# 278) sl_T_Theta                     0.001525
# 279) power_T_Theta                  0.001509
# 280) crossfreq_PO_Mbeta1_Beta3      0.001495
# 281) crossfreq_T_Mgamma_Beta1       0.001495
# 282) education                      0.001494
# 283) crossfreq_T_Mbeta2_Gamma       0.001493
# 284) entropy_F_Beta2                0.001484
# 285) crossfreq_C_Malpha-2_Gamma     0.001483
# 286) crossfreq_T_Mbeta1_Alpha-2     0.001476
# 287) crossfreq_C_Malpha-1_Beta1     0.001476
# 288) crossfreq_F_Malpha-2_Delta     0.001472
# 289) crossfreq_T_Mdelta_Gamma       0.001470
# 290) crossfreq_T_Malpha-1_Delta     0.001467
# 291) power_PO_Beta3                 0.001464
# 292) crossfreq_F_Malpha-2_Beta3     0.001460
# 293) entropy_T_Theta                0.001457
# 294) entropy_F_Theta                0.001450
# 295) crossfreq_C_Mbeta1_Theta       0.001449
# 296) crossfreq_T_Mtheta_Gamma       0.001448
# 297) crossfreq_PO_Mtheta_Beta1      0.001448
# 298) crossfreq_C_Mbeta1_Gamma       0.001443
# 299) crossfreq_F_Mbeta2_Beta2       0.001410
# 300) crossfreq_C_Mbeta1_Beta1       0.001407
# 301) crossfreq_PO_Mbeta1_Delta      0.001407
# 302) crossfreq_F_Mdelta_Beta3       0.001406
# 303) crossfreq_PO_Mbeta2_Gamma      0.001405
# 304) crossfreq_T_Malpha-2_Beta1     0.001399
# 305) crossfreq_PO_Mbeta1_Gamma      0.001399
# 306) crossfreq_T_Mbeta1_Gamma       0.001396
# 307) crossfreq_F_Mgamma_Alpha-1     0.001389
# 308) crossfreq_C_Mgamma_Beta1       0.001385
# 309) crossfreq_F_Malpha-2_Beta1     0.001384
# 310) crossfreq_PO_Mbeta2_Beta3      0.001380
# 311) crossfreq_F_Malpha-1_Theta     0.001363
# 312) crossfreq_C_Malpha-1_Beta2     0.001352
# 313) crossfreq_T_Mgamma_Alpha-1     0.001349
# 314) crossfreq_C_Mbeta2_Beta3       0.001339
# 315) crossfreq_T_Mbeta1_Beta3       0.001332
# 316) crossfreq_PO_Mbeta3_Delta      0.001322
# 317) crossfreq_C_Mbeta1_Delta       0.001308
# 318) crossfreq_T_Mdelta_Beta3       0.001300
# 319) power_C_Alpha-1                0.001292
# 320) power_T_Beta2                  0.001280
# 321) crossfreq_C_Mdelta_Alpha-1     0.001279
# 322) crossfreq_F_Mbeta3_Gamma       0.001268
# 323) crossfreq_PO_Malpha-1_Beta3    0.001265
# 324) crossfreq_F_Mbeta3_Alpha-1     0.001264
# 325) crossfreq_T_Mtheta_Delta       0.001261
# 326) crossfreq_PO_Mdelta_Alpha-1    0.001260
# 327) power_T_Alpha-1                0.001257
# 328) power_F_Beta2                  0.001256
# 329) crossfreq_C_Mtheta_Alpha-2     0.001235
# 330) crossfreq_F_Mbeta3_Delta       0.001219
# 331) power_F_Delta                  0.001194
# 332) crossfreq_F_Mbeta1_Alpha-2     0.001194
# 333) entropy_T_Beta2                0.001183
# 334) crossfreq_C_Mbeta2_Beta2       0.001176
# 335) power_F_Alpha-1                0.001175
# 336) crossfreq_C_Malpha-1_Beta3     0.001170
# 337) crossfreq_F_Mbeta1_Theta       0.001170
# 338) sl_T_Alpha-2                   0.001164
# 339) crossfreq_C_Mtheta_Theta       0.001163
# 340) crossfreq_C_Mbeta3_Beta1       0.001156
# 341) crossfreq_F_Mbeta2_Gamma       0.001151
# 342) crossfreq_F_Mbeta1_Beta2       0.001137
# 343) crossfreq_F_Mbeta1_Delta       0.001135
# 344) entropy_C_Gamma                0.001130
# 345) crossfreq_T_Mbeta1_Beta1       0.001117
# 346) crossfreq_F_Mdelta_Alpha-2     0.001105
# 347) crossfreq_F_Malpha-1_Alpha-2   0.001105
# 348) crossfreq_PO_Mtheta_Delta      0.001101
# 349) entropy_C_Theta                0.001099
# 350) crossfreq_F_Mbeta3_Alpha-2     0.001088
# 351) power_C_Gamma                  0.001077
# 352) crossfreq_C_Malpha-2_Beta1     0.001071
# 353) crossfreq_C_Malpha-1_Alpha-1   0.001070
# 354) crossfreq_F_Mbeta2_Alpha-1     0.001068
# 355) crossfreq_F_Malpha-1_Gamma     0.001065
# 356) crossfreq_PO_Mtheta_Alpha-2    0.001062
# 357) crossfreq_C_Mbeta1_Alpha-1     0.001061
# 358) crossfreq_F_Malpha-1_Beta3     0.001048
# 359) crossfreq_F_Mtheta_Beta2       0.001043
# 360) sl_F_Alpha-2                   0.001028
# 361) sl_PO_Alpha-2                  0.001024
# 362) crossfreq_T_Malpha-2_Gamma     0.001020
# 363) crossfreq_C_Mtheta_Alpha-1     0.001008
# 364) crossfreq_C_Mbeta1_Beta2       0.000990
# 365) crossfreq_F_Mbeta1_Gamma       0.000985
# 366) crossfreq_F_Malpha-1_Beta2     0.000983
# 367) crossfreq_F_Malpha-2_Alpha-1   0.000964
# 368) entropy_C_Beta3                0.000956
# 369) crossfreq_F_Mtheta_Delta       0.000956
# 370) crossfreq_C_Mbeta1_Beta3       0.000951
# 371) crossfreq_F_Malpha-1_Alpha-1   0.000935
# 372) crossfreq_C_Mbeta2_Beta1       0.000931
# 373) crossfreq_PO_Mtheta_Beta3      0.000928
# 374) crossfreq_C_Mbeta2_Delta       0.000914
# 375) crossfreq_T_Mbeta3_Beta1       0.000905
# 376) crossfreq_PO_Mbeta2_Alpha-2    0.000898
# 377) crossfreq_T_Malpha-1_Beta1     0.000863
# 378) crossfreq_C_Mbeta2_Theta       0.000850
# 379) crossfreq_F_Malpha-1_Delta     0.000843
# 380) crossfreq_C_Mbeta2_Alpha-1     0.000839
# 381) crossfreq_T_Mtheta_Beta1       0.000836
# 382) crossfreq_C_Mtheta_Delta       0.000819
# 383) crossfreq_C_Mdelta_Theta       0.000802
# 384) crossfreq_C_Malpha-2_Alpha-2   0.000797
# 385) crossfreq_F_Mbeta1_Alpha-1     0.000784
# 386) power_C_Delta                  0.000709
# 387) MM_total                       0.000468
# 388) sex                            0.000109

# %%
for index, feature_name in enumerate(sorted_names,start=1):

    input_features_names = sorted_names[:index]
    input_features_index = [data.columns.get_loc(c) for c 
                      in input_features_names if c in data]
    feature_model = best_selected.fit(X_train[:, input_features_index], y_train)
    scores = cross_val_score(
                        estimator=feature_model,
                        X=X_train[:, input_features_index],
                        y=y_train,
                        cv=10,
                        n_jobs=-1
                        )
    
  
    modelos['number_features_' + str(index)] = feature_model
    acc_per_feature.append(np.mean(scores))
    std_per_feature.append(np.std(scores))


#plt.plot(
#        range(1, len(sorted_names)),
#        acc_per_feature,
#        color='red'
#        ) 
#
#plt.fill_between(
#                range(1, len(sorted_names)),
#                np.array(acc_per_feature) + np.array(std_per_feature),
#                np.array(acc_per_feature) - np.array(std_per_feature),
#                alpha=0.15,
#                color='red'
#                )

plt.plot(
        range(1, len(acc_per_feature)+1),
        acc_per_feature,
        color='red'
        ) 

plt.fill_between(
                range(1, len(acc_per_feature)+1),
                np.array(acc_per_feature) + np.array(std_per_feature),
                np.array(acc_per_feature) - np.array(std_per_feature),
                alpha=0.15,
                color='red'
                )

plt.grid()
plt.savefig(path_plot+'/'+'features_plot.png')
plt.show()

# %%
pos_model = np.argsort(acc_per_feature)[-1]
best_model = list(modelos.keys())[pos_model]
best_model
# Out:
# 'number_features_6'

# %%
joblib.dump(modelos[best_model], path_plot+'/'+'modelo_entrenado.pkl') # Guardo el modelo.
# Out:
# ['C:\\Users\\veroh\\OneDrive - Universidad de Antioquia\\Articulo análisis longitudinal\\Resultados_Armonizacion_BD\\Graficos_ML/neuroHarmonize_G2G1/modelo_entrenado.pkl']

# %%
# Guardar mejore carateristicas
best_features=sorted_names[:pos_model]
mi_path = path_plot+'/'+"best_features.txt"
f = open(mi_path, 'w')

for i in best_features:
    f.write(i+'\n')
f.close()

# %%
new_data = pd.DataFrame()
for i in range(0,len(data.columns)):
    for j in range(0,len(best_features)):
        if data.columns[i] == best_features[j]:
            new_data[best_features[j]] = data[best_features[j]]

# %%
new_name = 'Data_complete_randomforest'+space+'_'+name
new_data.reset_index(drop=True).to_feather('{path}\Datosparaorganizardataframes\ML\{name}.feather'.format(path=path,name=new_name))

# %%
sns.heatmap(new_data.corr())
plt.savefig(path_plot+'/'+'correlation_randomforest.png')

# %%
selected_best_features = [new_data.columns.get_loc(c) for c in best_features if c in new_data]
selected_best_features
# Out:
# [2, 4, 0, 3, 5, 6, 1]

# %%
predicted = feature_model.predict(X_test[:,input_features_index])
classes_x=(predicted >= 0.5).astype(int)
computerprecision(y_test,classes_x)
# Out:
# Precision:  0.4666666666666667
#  Recall:  0.6363636363636364
#  F1-score: 0.5384615384615385

# %%
class_names=['G1','G2']
cm_test = confusion_matrix(y_test,classes_x)
plot_confusion_matrix(path_plot,cm_test,classes=class_names,title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[2 8]
#  [4 7]]

# %%
train_sizes, train_scores, test_scores = \
    learning_curve(
                  estimator=modelos[best_model],
                  X=X_test[selected_best_features],## Revisar
                  y=y_train[selected_best_features],
                  train_sizes=np.linspace(0.1, 1, 10),
                  cv=10,
                  n_jobs=-1
                  )
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)# test_score
test_std = np.std(test_scores, axis=1)

plt.plot(
        train_sizes,
        train_mean,
        color='blue',
        marker='o',
        markersize=5,
        label='training accuracy'
        )

plt.fill_between(
                train_sizes,
                train_mean + train_std,
                train_mean - train_std,
                alpha=0.15,
                color='blue'
                )

plt.plot(
        train_sizes,
        test_mean,
        color='green',
        linestyle='--',
        marker='s',
        markersize=5,
        label='validation accuracy'
        )

plt.fill_between(
                train_sizes,
                test_mean + test_std,
                test_mean - test_std,
                alpha=0.15,
                color='green'
                )

plt.grid()
plt.xlabel('number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.5, 1.0])
plt.savefig(path_plot+'/'+'validation_randomforest.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 train_sizes, train_scores, test_scores = \
# ----> 2     learning_curve(
#       3                   estimator=modelos[best_model],
#       4                   X=X_test[selected_best_features],## Revisar
#       5                   y=y_train[selected_best_features],
#       6                   train_sizes=np.linspace(0.1, 1, 10),
#       7                   cv=10,
#       8                   n_jobs=-1
#       9                   )
#      10 train_mean = np.mean(train_scores, axis=1)
#      11 train_std = np.std(train_scores, axis=1)
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:1552, in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1550 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#    1551 # Store it as list as we will be iterating over the list multiple times
# -> 1552 cv_iter = list(cv.split(X, y, groups))
#    1554 scorer = check_scoring(estimator, scoring=scoring)
#    1556 n_max_training_samples = len(cv_iter[0][0])
#
# File c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:345, in _BaseKFold.split(self, X, y, groups)
#     343 n_samples = _num_samples(X)
#     344 if self.n_splits > n_samples:
# --> 345     raise ValueError(
#     346         (
#     347             "Cannot have number of splits n_splits={0} greater"
#     348             " than the number of samples: n_samples={1}."
#     349         ).format(self.n_splits, n_samples)
#     350     )
#     352 for train, test in super().split(X, y, groups):
#     353     yield train, test
#
# ValueError: Cannot have number of splits n_splits=10 greater than the number of samples: n_samples=7.

# %% [markdown]
# ### SVM (Grid Search)

# %%
svm_param_grid = {'C': list(np.logspace(-1, 4, 6)), 
                 'gamma': list(np.logspace(-3, 2, 6)) + ['Auto'] + ['scale'],
                 'kernel': ['rbf', 'poly']} 

svc = SVC()
svc_clf = GridSearchCV(
                      svc,
                      svm_param_grid,
                      n_jobs=-1,
                      cv=10
                      )

svm_best_clf = svc_clf.fit(X_train, y_train)
best_model = svm_best_clf.best_estimator_
# Out:
# c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 88 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'gamma' parameter of SVC must be a str among {'scale', 'auto'} or a float in the range [0.0, inf). Got 'Auto' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 180, in fit
#     self._validate_params()
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\veroh\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'gamma' parameter of SVC must be a str among {'auto', 'scale'} or a float in the range [0.0, inf). Got 'Auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\veroh\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.5    0.5875 0.5    0.55   0.4875 0.55   0.4875 0.55   0.4875 0.55
#  0.5125 0.55      nan    nan 0.5    0.5    0.625  0.55   0.625  0.55
#  0.5    0.55   0.4875 0.55   0.4875 0.55   0.5125 0.55      nan    nan
#  0.5    0.525  0.7    0.55   0.55   0.55   0.5    0.55   0.4875 0.55
#  0.4875 0.55   0.5125 0.55      nan    nan 0.5625 0.65   0.575  0.55
#  0.55   0.55   0.5    0.55   0.4875 0.55   0.4875 0.55   0.5125 0.55
#     nan    nan 0.675  0.7    0.6    0.55   0.55   0.55   0.5    0.55
#  0.4875 0.55   0.4875 0.55   0.5125 0.55      nan    nan 0.6875 0.7125
#  0.6    0.55   0.55   0.55   0.5    0.55   0.4875 0.55   0.4875 0.55
#  0.5125 0.55      nan    nan 0.625  0.5875]
#   warnings.warn(

# %%
best_model.fit(X_train, y_train)
# Out:
# SVC(C=1000.0, kernel='poly')

# %%
predicted = best_model.predict(X_test)

# %%
print(
    f"Classification report for classifier {best_model}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
    )
# Out:
# Classification report for classifier SVC(C=1000.0, kernel='poly'):
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.50      0.43        10
#          1.0       0.38      0.27      0.32        11
#
#     accuracy                           0.38        21
#    macro avg       0.38      0.39      0.38        21
# weighted avg       0.38      0.38      0.37        21

# %%
dataframe_metrics = metrics.classification_report(y_test, predicted, output_dict=True)
dataframe_metrics = pd.DataFrame(dataframe_metrics).T
dfi.export(dataframe_metrics, path_plot+'/'+'metrics_SVM.png')
# Out:
# C:\Program Files\Google\Chrome\Application\chrome.exe

# %% [markdown]
# ### SVM (Permutation importance)

# %%
# results = permutation_importance(
#                                 best_model,
#                                 X_train,
#                                 y_train,
#                                 scoring='accuracy'
#                                 )

# nombres_columnas = data.columns[:-1]
# importance = results.importances_mean
# index = np.argsort(importance)

# for v, idx in zip(importance, index):
    
#     print(f'Feature: {nombres_columnas[idx]} | Score: {v}')

# %% [markdown]
# ### SVM con caracteristicas seleccionadas del árbol de decisión

# %%
acc_per_feature = []
std_per_feature = []

for index, feature_name in enumerate(sorted_names,start=1):

    input_features_names = sorted_names[:index]
    input_features_index = [data.columns.get_loc(c) for c 
                      in input_features_names if c in data]
    best_model.fit(X_train[:, input_features_index], y_train)
    scores = cross_val_score(
                        estimator=best_model,
                        X=X_train[:, input_features_index],
                        y=y_train,
                        cv=10,
                        n_jobs=-1
                        )
    acc_per_feature.append(np.mean(scores))
    std_per_feature.append(np.std(scores))

plt.plot(
        range(0, len(sorted_names)),
        acc_per_feature,
        color='red'
        ) 

plt.fill_between(
                range(0, len(sorted_names)),
                np.array(acc_per_feature) + np.array(std_per_feature),
                np.array(acc_per_feature) - np.array(std_per_feature),
                alpha=0.15,
                color='red'
                )

plt.grid()

# %% [markdown]
# ### XGBoosting

# %% [markdown]
# ### TPOT

# %%
pipeline_optimizer = TPOTClassifier()

# %%
pipeline_optimizer = TPOTClassifier(
                                    generations=5,
                                    population_size=int(X.shape[0]*0.4),
                                    cv=10,
                                    random_state=10,
                                    verbosity=3,
                                    n_jobs=-1
                                    )

# %%
pipeline_optimizer.fit(X_train, y_train)
# Out:
# 32 operators have been imported by TPOT.
# Optimization Progress:   0%|          | 0/240 [00:00<?, ?pipeline/s]
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
#
# Generation 1 - Current Pareto front scores:
#
# -1	0.75	DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 89.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required by DecisionTreeClassifier..
#
# Generation 2 - Current Pareto front scores:
#
# -1	0.75	DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
# Skipped pipeline #157 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	0.75	DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Skipped pipeline #195 due to time out. Continuing to the next pipeline.
#
# Generation 4 - Current Pareto front scores:
#
# -1	0.75	DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
#
# -3	0.7625	DecisionTreeClassifier(XGBClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.2), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=15, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.3, XGBClassifier__verbosity=0), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 67.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required by DecisionTreeClassifier..
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#
# Generation 5 - Current Pareto front scores:
#
# -1	0.75	DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
#
# -2	0.7625	DecisionTreeClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.2), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=6)
# TPOTClassifier(cv=10, generations=5, n_jobs=-1, population_size=40,
#                random_state=10, verbosity=3)

# %%
print(pipeline_optimizer.score(X_test, y_test))
# Out:
# 0.47619047619047616
# c:\Users\veroh\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py:794: FutureWarning: sklearn.metrics.SCORERS is deprecated and will be removed in v1.3. Please use sklearn.metrics.get_scorer_names to get a list of available scorers and sklearn.metrics.get_metric to get scorer.
#   warnings.warn(
