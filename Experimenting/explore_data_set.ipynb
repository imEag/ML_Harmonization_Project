# %%
# open and show dataframe from ./neuroHarmonize/integration2to1/ic/G1/Data_complete_ic_neuroHarmonize_G1_54x10.feather

import pandas as pd

df = pd.read_feather('./neuroHarmonize/integration2to1/ic/G1/Data_complete_ic_neuroHarmonize_G1_54x10.feather')

df
# Out:
#      power_C1_Delta  power_C1_Theta  power_C1_Alpha-1  power_C1_Alpha-2  \
# 0          0.105419        0.061867          0.263933          0.359296
# 1          0.074648        0.049414          0.537421          0.355535
# 2          0.127089        0.059033          0.313437          0.188218
# 3          0.094227        0.037191          0.305044          0.263479
# 4          0.146821        0.160562          0.494792          0.152230
# ..              ...             ...               ...               ...
# 142        0.179319        0.087104          0.323202          0.225764
# 143        0.056217        0.051040          0.597322          0.126578
# 144        0.134710        0.072139          0.352626          0.263595
# 145        0.126420        0.064147          0.215086          0.328707
# 146        0.168872        0.100585          0.307603          0.183302
#
#      power_C1_Beta1  power_C1_Beta2  power_C1_Beta3  power_C1_Gamma  \
# ...

# %%
# show all column names
df.columns
# show all column names in a list
print(list(df.columns))
# Out:
# ['power_C1_Delta', 'power_C1_Theta', 'power_C1_Alpha-1', 'power_C1_Alpha-2', 'power_C1_Beta1', 'power_C1_Beta2', 'power_C1_Beta3', 'power_C1_Gamma', 'power_C2_Delta', 'power_C2_Theta', 'power_C2_Alpha-1', 'power_C2_Alpha-2', 'power_C2_Beta1', 'power_C2_Beta2', 'power_C2_Beta3', 'power_C2_Gamma', 'power_C3_Delta', 'power_C3_Theta', 'power_C3_Alpha-1', 'power_C3_Alpha-2', 'power_C3_Beta1', 'power_C3_Beta2', 'power_C3_Beta3', 'power_C3_Gamma', 'power_C4_Delta', 'power_C4_Theta', 'power_C4_Alpha-1', 'power_C4_Alpha-2', 'power_C4_Beta1', 'power_C4_Beta2', 'power_C4_Beta3', 'power_C4_Gamma', 'power_C5_Delta', 'power_C5_Theta', 'power_C5_Alpha-1', 'power_C5_Alpha-2', 'power_C5_Beta1', 'power_C5_Beta2', 'power_C5_Beta3', 'power_C5_Gamma', 'power_C6_Delta', 'power_C6_Theta', 'power_C6_Alpha-1', 'power_C6_Alpha-2', 'power_C6_Beta1', 'power_C6_Beta2', 'power_C6_Beta3', 'power_C6_Gamma', 'power_C7_Delta', 'power_C7_Theta', 'power_C7_Alpha-1', 'power_C7_Alpha-2', 'power_C7_Beta1', 'power_C7_Beta2
# ...

# %%
# show these columns: 'database', 'participant_id', 'visit', 'condition', 'group', 'sex', 'age', 'MM_total', 'FAS_F', 'FAS_S', 'FAS_A', 'education',

df[['database', 'participant_id', 'visit', 'condition', 'group', 'sex', 'age', 'MM_total', 'FAS_F', 'FAS_S', 'FAS_A', 'education']]
# Out:
#           database participant_id visit condition    group sex  age  MM_total  \
# 0    BIOMARCADORES      sub-G1001    V0        CE       G1   M   28      30.0
# 1    BIOMARCADORES      sub-G1017    V0        CE       G1   M   29      30.0
# 2    BIOMARCADORES      sub-G1002    V0        CE       G1   F   30      30.0
# 3    BIOMARCADORES      sub-G1000    V0        CE       G1   F   22      29.0
# 4    BIOMARCADORES      sub-G1015    V0        CE       G1   F   40      30.0
# ..             ...            ...   ...       ...      ...  ..  ...       ...
# 142          CHBMP   sub-CBM00156    V0   protmap  Control   F   29      30.0
# 143          CHBMP   sub-CBM00147    V0   protmap  Control   F   30      28.0
# 144          CHBMP   sub-CBM00202    V0   protmap  Control   M   22      30.0
# 145          CHBMP   sub-CBM00283    V0   protmap  Control   F   31      30.0
# 146          CHBMP   sub-CBM00284    V0   protmap  Control   M   19      26.0
#
# ...

# %%
# show all unique values of the column 'group'
df['group'].unique()
# Out:
# array(['G1', 'Control'], dtype=object)

# %%
df['condition'].unique()
# Out:
# array(['CE', 'resting', 'resteyesc', 'protmap'], dtype=object)
